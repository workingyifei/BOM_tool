# %% [markdown]
# ### The script below syncs the supply Chain BOM with CAD BOM.
# ### Created by Yifei.li@byton.com

# %%
import pandas as pd
import numpy as np
import xlrd, openpyxl
import csv, datetime
import time

# %%
#load CAD_BOM and SCBOM
def load():
    # load Engineering BOM
    # CAD_BOM = pd.read_csv(CAD_BOM_PATH)
    CAD_BOM = pd.read_excel(CAD_BOM_PATH, sheet_name="BOM", skiprows=1)
    CAD_BOM.columns = CAD_BOM.columns.str.replace("\(R\)\ ", "") # trim (R) away from the header

    CAD_BOM.loc[CAD_BOM.System=="N Intelligent Car Experience ICE", "System"]= "N ICE"
    CAD_BOM = CAD_BOM.rename(index=str, columns={"Byton Part number": "Byton PN"})
    CAD_BOM = CAD_BOM.reset_index(drop=True)

    #     # load Supply Chain BOM from MULTIPLE tabs in an Excel
    #     df= pd.read_excel(SCBOM_PATH, sheet_name=system_name)
    #     SCBOM = pd.DataFrame()
    #     for each in df:
    #         SCBOM = SCBOM.append(df[each])

    # load Supply Chain BOM from SINGLE TAB in an Excel
    SCBOM= pd.read_excel(SCBOM_PATH, sheet_name="Supply Chain BOM")

    # change column N Intelligent Car Experience ICE to just N ICE
    # pd.to_excel doesn't allow column name greater than 31 characters
    SCBOM.loc[SCBOM.System=="N Intelligent Car Experience ICE", "System"]= "N ICE"

    # reset index of SCBOM
    SCBOM.reset_index(drop=True, inplace=True)
    print("\nComplete loading excel files\n")
    return CAD_BOM, SCBOM

# %%
# search PN and/or Rev in SCBOM
def search(df, PN, Rev):
    # df = df.loc[(df["Title"]==PN) & (df["Revision"]==Rev)]
    df = df.loc[(df["Title"]==PN)]	# search PN only 
    index = df.index.values
    
    # only one entry found
    if (len(index)==1):
        return index   
    
    # multiple entries found
    elif (len(index)>1):
        #return the first index if duplicate PN and Rev found
        return index.tolist()   # returned indexes are a numpy.ndarray, we convert to a list and get the first value
    
    # no entry found
    else:
        return None

# %%
# copy SCBOM info and paste into SCBOM_updated
def copy_and_paste_row(df1, index1, df2, index2):  # index1 and index2 are int
    # copy df2 info into df1
    # only copy columns that are not on CAD_BOM
	df1.loc[index1, df1.columns.tolist()[SCBOM_updated_columns_start:SCBOM_updated_columns_end]] = df2.loc[index2, df2.columns.tolist()[SCBOM_columns_start:SCBOM_columns_end]]
	return df1

# %%
# save dataframe to Excel
def save(df):
	#https://stackoverflow.com/questions/28837057/pandas-writing-an-excel-file-containing-unicode-illegalcharactererror
	df = df.applymap(lambda x: x.encode('unicode_escape').
	             decode('utf-8') if isinstance(x, str) else x)
	date = str(datetime.date.today())
	name = "Supply Chain BOM_" + date + ".xlsx"
	writer = pd.ExcelWriter(name)
	print("\nStart saving...\n")

	# saving to multiple tabs
	for each in system_name:
		system = df[df["System"]==each]
		print("\rsaving: {}".format(each), end="", flush=True)
		system.to_excel(writer, sheet_name=each, na_rep="")
	
	print("\nSaving complete...\n")
	# # saving to ONE tab
	# df.to_excel(writer, sheet_name="Updated Supply Chain BOM", na_rep="" )

	writer.save()

#     df.to_csv("Supply Chain BOM.csv",quoting=csv.QUOTE_NONE, escapechar="\\")

# %%
start_time = time.time()

# put up-to-date CAD_BOM and SCBOM here for sync
CAD_BOM_PATH = './Data/AAZZ000001NN03_VP_BoM_10-15-18.xlsx'
SCBOM_PATH = './Data/Copy of Supply Chain BOM_2018-10-03_final.xlsx'


# tab names in supply chain BOM.xlsx and CAD_BOM.xlsx
system_name = ["A BIW", "B Closures", "C Exterior", "D Interior", "E Chassis", "F Thermal Management", "G Drivetrain",
              "H Power Electronics", "J HV Battery", "K Autonomy", "L Low Voltage Systems", "M Connectivity", 
              "N ICE", "X Raw Materials", "Y Fasteners", "Z Vehicle Top Level Cfg"]



CAD_BOM, SCBOM = load()

# create Parent and Level column in CAD_BOM
CAD_BOM.insert(0, column="Level", value="")
CAD_BOM.insert(1, column="Parent", value="")

for index, row in CAD_BOM.iterrows():
    identifier = str(row["Identifier"]) 
    level = identifier.count("|")
    CAD_BOM.loc[index, ["Level"]] = level
    
    identifier_parent = identifier[0:-2]
    PN_parent = CAD_BOM[CAD_BOM["Identifier"]==identifier_parent]["Byton PN"]
    if PN_parent.empty == True:
        PN_parent = ""
    else:
        PN_parent = PN_parent.values
    CAD_BOM.loc[index, ["Parent"]] = PN_parent
    
    
# create a updated SCBOM with columns from SCBOM and data from CAD_BOM
SCBOM_updated = CAD_BOM.copy()
# copy only colums that do not exist in CAD_BOM
for each in SCBOM.columns.tolist()[SCBOM_columns_start:]:
    SCBOM_updated[each] = ""
    

# needs to change the followings based on how the CAD_BOM and SCBOM columns are structured 
# 0 index
SCBOM_columns_start = 14 # Supply Chain info starts at column # 14 in SCBOM
SCBOM_columns_end = SCBOM.shape[1] 
SCBOM_updated_columns_start = CAD_BOM.shape[1]
SCBOM_updated_columns_end = SCBOM.shape[1] + SCBOM_updated_columns_start-SCBOM_columns_start




SCBOM_columns = SCBOM.columns.tolist()
SCBOM_columns_size = len(SCBOM_columns)
CAD_BOM_columns = CAD_BOM.columns.tolist()
CAD_BOM_columns_size = len(CAD_BOM_columns)

print("Before Sync")
print("CAD_BOM shape: ", CAD_BOM.shape)
print("SCBOM shape: ", SCBOM.shape)
print("SCBOM_updated: {}\n".format(SCBOM_updated.shape))


# count how many new parts are added
# how many old parts are removed
removed_parts_count = 0
same_parts = 0
# Out:
# Complete loading excel files
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b920398a9a76> in <module>()
#      36 SCBOM_updated = CAD_BOM.copy()
#      37 # copy only colums that do not exist in CAD_BOM
# ---> 38 for each in SCBOM.columns.tolist()[SCBOM_columns_start:]:
#      39     SCBOM_updated[each] = ""
#      40
#
# NameError: name 'SCBOM_columns_start' is not defined

# %%
# loop through SCBOM 
for index, row in SCBOM.iterrows():
    print("\rUpdating row # {0} of Supply Chain BOM. Progress: {1}%".format(index, round(index*100/SCBOM.shape[0]), 4), end="", flush=True)
    PN = row["Title"]
    Rev = row["Revision"]
    # same part could be structured differently but the part is the same, 
    # so if same part found at multiple places, we will just pick one
    # Identifier = row["Identifier"] 

    # search if this part exists in SCBOM_updated, return the index in SCBOM_updated
    # search() returned a list or None type
    index_SCBOM_updated = search(SCBOM_updated, PN, Rev)

    #not found, deactivate the part, then append this part to SCBOM_updated
    if (index_SCBOM_updated == None):
        SCBOM.loc[index, ["Part Active"]] = "Inactivate"
        SCBOM.loc[index, ["Part Status"]] = "Removed"
        # SCBOM.loc[index, ["Part Creation Date"]] = datetime.date(2019, 9, 14)
        SCBOM.loc[index, ["Last Modified Date"]] = datetime.date.today()
        # SCBOM.loc[index, ["Last Modified Date"]] = datetime.date(2019, 9, 28)
        columns_to_copy = SCBOM.columns.tolist()[SCBOM_columns_start:SCBOM_columns_end]
        other_columns = ["Title", "Revision", "Description", "System", "SubSystem", "Part Type"]
        columns_to_copy = columns_to_copy + other_columns
        SCBOM_updated = SCBOM_updated.append(SCBOM.loc[index, columns_to_copy], ignore_index=True)

        removed_parts_count = removed_parts_count + 1

    # found one entry, copy the information to updated SCBOM    
    elif (len(index_SCBOM_updated) == 1):
        index_SCBOM_updated = index_SCBOM_updated[0]
        SCBOM_updated = copy_and_paste_row(SCBOM_updated, index_SCBOM_updated, SCBOM, index)
        SCBOM_updated.loc[index_SCBOM_updated, ["Part Creation Date"]] = datetime.date(2019, 9, 21)
        # SCBOM_updated.loc[index_SCBOM_updated, ["Last Modified Date"]] = datetime.date.today()
        SCBOM_updated.loc[index_SCBOM_updated, ["Part Status"]] = "Lateste Revision"
        SCBOM_updated.loc[index_SCBOM_updated, ["Part Active"]] = "Active"
        same_parts = same_parts + 1

    # found multiple entries, copy the information to each of the entries in SCBOM_updated
    else:
        for each in index_SCBOM_updated:
            SCBOM_updated = copy_and_paste_row(SCBOM_updated, each, SCBOM, index)
            SCBOM_updated.loc[index_SCBOM_updated, ["Part Creation Date"]] = datetime.date(2019, 9, 21)
            # SCBOM_updated.loc[index_SCBOM_updated, ["Last Modified Date"]] = datetime.date.today()
            SCBOM_updated.loc[index_SCBOM_updated, ["Part Status"]] = "Lateste Revision"
            SCBOM_updated.loc[index_SCBOM_updated, ["Part Active"]] = "Active"
        same_parts = same_parts + 1

save(SCBOM_updated)

print("After Sync")
print("CAD_BOM shape: ", CAD_BOM.shape)
print("SCBOM shape: ", SCBOM.shape)
print("SCBOM_updated ", SCBOM_updated.shape)


print("\n# of new parts added: ", CAD_BOM.shape[0]-same_parts)
print("# of old parts removed: ", removed_parts_count)
print("# of additional columns added in CAD_BOM: ", SCBOM_updated.shape[1] - SCBOM.shape[1])


execution_time = round(time.time() - start_time, 2)
print("\nThis script took--- {} seconds ---".format(execution_time))

# %% [markdown]
# ### create Parent and Level column in CAD_BOM

# %%
CAD_BOM, SCBOM = load()
# Out:
# Complete loading excel files

# %%
CAD_BOM.head(5)
# Out:
#   Identifier        Byton PN Revision                           Title  QTY  \
# 0          0  AAZZ000001NN03      A.1                   PHTM EC001 VP    1
# 1          1  AAAZ000002NN03      A.1                     PHTM BIW VP    1
# 2        1|1  AAAG000002NN03      A.1  PHTM BIW BODY STRUCTURE ASM VP    1
# 3      1|1|1  AAAG002892NN00      A.1             COMPLETE WELDED BIW    1
# 4    1|1|1|1  AAAG003784NN00      A.1      JOINING ELEMENTS UPPERBODY    1
#
#                       Description      UOM Purchased Part Type Maturity  \
# 0                   PHTM EC001 VP  EA EACH             Phantom  In Work
# 1                     PHTM BIW VP  EA EACH             Phantom  In Work
# 2  PHTM BIW BODY STRUCTURE ASM VP  EA EACH             Phantom  In Work
# 3             COMPLETE WELDED BIW  EA EACH                Make  In Work
# 4      JOINING ELEMENTS UPPERBODY  EA EACH             Phantom  In Work
#
#   Part Type                   System                    SubSystem  \
# 0   Phantom  Z Vehicle Top Level Cfg                       Z Z NA
# 1   Phantom                    A BIW                       A Z NA
# 2   Phantom                    A BIW  A G Body Structure Assembly
# 3  Assembly                    A BIW  A G Body Structure Assembly
# 4   Phantom                    A BIW  A G Body Structure Assembly
#
#   Legacy Part Number Legacy Part Revision Effectivity
# 0                NaN                  NaN         NaN
# 1                NaN                  NaN         NaN
# 2                NaN                  NaN         NaN
# 3   EC001_02_130_000                  NaN         NaN
# 4                NaN                  NaN         NaN

# %%
CAD_BOM.insert(0, column="Level", value="")
CAD_BOM.insert(1, column="Parent", value="")

for index, row in CAD_BOM.iterrows():
    identifier = str(row["Identifier"]) 
    level = identifier.count("|")
    CAD_BOM.loc[index, ["Level"]] = level
    
    identifier_parent = identifier[0:-2]
    if identifier_parent == '':
        identifier_parent = ''
    elif identifier_parent[-1]=='|':
        identifier_parent = identifier_parent[0:-1]
    else:
        identifier_parent = identifier_parent
        
    PN_parent = CAD_BOM[CAD_BOM["Identifier"]==identifier_parent]["Byton PN"]
    if PN_parent.empty == True:
        PN_parent = ""
    else:
        PN_parent = PN_parent.values
    CAD_BOM.loc[index, ["Parent"]] = PN_parent

# date = str(datetime.date.today()) 
# name = "CAD BOM with Parent#_" + date + ".xlsx"
# writer = pd.ExcelWriter(name)
# CAD_BOM.to_excel(writer, sheet_name=name, na_rep="" )
# writer.save()

# %%
CAD_BOM.head(200)
# Out:
#      Level          Parent           Identifier        Byton PN Revision  \
# 0        0                                    0  AAZZ000001NN03      A.1
# 1        0                                    1  AAAZ000002NN03      A.1
# 2        1                                  1|1  AAAG000002NN03      A.1
# 3        2  AAAG000002NN03                1|1|1  AAAG002892NN00      A.1
# 4        3  AAAG002892NN00              1|1|1|1  AAAG003784NN00      A.1
# 5        3  AAAG002892NN00              1|1|1|2  AAAG005293NN00      A.1
# 6        3  AAAG002892NN00              1|1|1|3  AAAE003419NN00      A.1
# 7        4  AAAE003419NN00            1|1|1|3|1  AAAE003419NNFN      A.1
# 8        4  AAAE003419NN00            1|1|1|3|2  AAAE003418NL00      A.1
# 9        5  AAAE003418NL00          1|1|1|3|2|1  AAAE003418NLFN      A.1
# 10       5  AAAE003418NL00          1|1|1|3|2|2  AAAE003423NL00      A.1
# 11       5  AAAE003418NL00          1|1|1|3|2|3  AAAE002894NL00      A.1
# 12       5  AAAE003418NL00          1|1|1|3|2|4  AAAE003559NL00      A.1
# 13       5  AAAE003418NL00          1|1|1|3|2|5  AAAE003559NLFN      A.1
# 14       6  AAAE003559NLFN        1|1|1|3|2|5|1  AAYF000148NN00      A.1
# 15       5  AAAE003418NL00          1|1|1|3|2|6  AAAE003421NL00      A.1
# 16       5  AAAE003418NL00          1|1|1|3|2|7  AAAE003421NLFN      A.1
# 17       6  AAAE003421NLFN        1|1|1|3|2|7|1  AAYF000148NN00      A.1
# 18       6                        1|1|1|3|2|9|1  AAYF000148NN00      A.1
# 19       6                       1|1|1|3|2|11|1  AAYF000148NN00      A.1
# 20       5  AAAE003418NL00         1|1|1|3|2|12  AAAE003417NL00      A.1
# 21       6  AAAE003417NL00       1|1|1|3|2|12|1  AAAE003417NLFN      A.1
# 22       6  AAAE003417NL00       1|1|1|3|2|12|2  AAAE003476NL00      A.1
# 23       6  AAAE003417NL00       1|1|1|3|2|12|3  AAAE003476NLFN      A.1
# 24       7  AAAE003476NLFN     1|1|1|3|2|12|3|1  AAYD000193NN00      A.1
# 25       6  AAAE003417NL00       1|1|1|3|2|12|4  AAAE003465NL00      A.1
# 26       6  AAAE003417NL00       1|1|1|3|2|12|5  AAAE003465NLFN      A.1
# 27       7  AAAE003465NLFN     1|1|1|3|2|12|5|1  AAAC001627RN00      A.1
# 28       4  AAAE003419NN00            1|1|1|3|3  AAAE003418NR00      A.1
# 29       5  AAAE003418NR00          1|1|1|3|3|1  AAAE003423NR00      A.1
# ..     ...             ...                  ...             ...      ...
# 170      8  AAAE003512RLFN    1|1|1|3|4|5|4|5|1  AAYD000193NN00      A.1
# 171      7  AAAE003506RL00      1|1|1|3|4|5|4|6  AAAJ005335RL00      A.1
# 172      6  AAAE003452NL00        1|1|1|3|4|5|5  AAAE003505NL00      A.1
# 173      7  AAAE003505NL00      1|1|1|3|4|5|5|1  AAAE003505NLFN      A.1
# 174      7  AAAE003505NL00      1|1|1|3|4|5|5|2  AAAE003514NL00      A.1
# 175      7  AAAE003505NL00      1|1|1|3|4|5|5|3  AAAE003504NL00      A.1
# 176      8  AAAE003504NL00    1|1|1|3|4|5|5|3|1  AAAE003504NLFN      A.1
# 177      8  AAAE003504NL00    1|1|1|3|4|5|5|3|2  AAAE003510NL00      A.1
# 178      8  AAAE003504NL00    1|1|1|3|4|5|5|3|3  AAAE003507NL00      A.1
# 179      6  AAAE003452NL00        1|1|1|3|4|5|6  AAAE003503RL00      A.1
# 180      7  AAAE003503RL00      1|1|1|3|4|5|6|1  AAAE003503RLFN      A.1
# 181      7  AAAE003503RL00      1|1|1|3|4|5|6|2  AAAE003509RL00      A.1
# 182      7  AAAE003503RL00      1|1|1|3|4|5|6|3  AAAE003511RL00      A.1
# 183      7  AAAE003503RL00      1|1|1|3|4|5|6|4  AAAE003511RLFN      A.1
# 184      8  AAAE003511RLFN    1|1|1|3|4|5|6|4|1  AAYD000193NN00      A.1
# 185      5  AAAG003459NN00          1|1|1|3|4|6  AAAE003452NR00      A.1
# 186      6  AAAE003452NR00        1|1|1|3|4|6|1  AAAE003451NR00      A.1
# 187      7  AAAE003451NR00      1|1|1|3|4|6|1|1  AAAJ005810NR00      A.1
# 188      7  AAAE003451NR00      1|1|1|3|4|6|1|2  AAAJ005811NR00      A.1
# 189      7  AAAE003451NR00      1|1|1|3|4|6|1|3  AAAJ005809FR00      A.1
# 190      7  AAAE003451NR00      1|1|1|3|4|6|1|4  AAAE004607NN00      A.1
# 191      7  AAAE003451NR00      1|1|1|3|4|6|1|5  AAAE003489FR00      A.1
# 192      7  AAAE003451NR00      1|1|1|3|4|6|1|6  AAAE004760NR00      A.1
# 193      8  AAAE004760NR00    1|1|1|3|4|6|1|6|1  AAAE003495NR00      A.1
# 194      8  AAAE004760NR00    1|1|1|3|4|6|1|6|2  AAAE003487RR00      A.1
# 195      7  AAAE003451NR00      1|1|1|3|4|6|1|7  AAAE003448FR00      A.1
# 196      8  AAAE003448FR00    1|1|1|3|4|6|1|7|1  AAAE003474FR00      A.1
# 197      8  AAAE003448FR00    1|1|1|3|4|6|1|7|2  AAAE003474FRFN      A.1
# 198      9  AAAE003474FRFN  1|1|1|3|4|6|1|7|2|1  AAYD000193NN00      A.1
# 199      8  AAAE003448FR00    1|1|1|3|4|6|1|7|3  AAAE003462FR00      A.1
#
#                                      Title  QTY  \
# 0                            PHTM EC001 VP    1
# 1                              PHTM BIW VP    1
# 2           PHTM BIW BODY STRUCTURE ASM VP    1
# 3                      COMPLETE WELDED BIW    1
# 4               JOINING ELEMENTS UPPERBODY    1
# 5                         STUDS UPPER BODY    1
# 6                   ASSEMBLY OUTER FRAMING    1
# 7              JEP  ASSEMBLY OUTER FRAMING    1
# 8           ASSEMBLY SIDE FRAME OUTER LEFT    1
# 9      JEP  ASSEMBLY SIDE FRAME OUTER LEFT    1
# 10                      BODY SIDE PANEL LH    1
# 11                         REARLIGHT SHEET    1
# 12                           HOLDER FENDER    3
# 13                         FNHOLDER FENDER    3
# 14                        RIVET NUT HEX M6    1
# 15                           HOLDER FENDER    1
# 16                         FNHOLDER FENDER    1
# 17                        RIVET NUT HEX M6    2
# 18                        RIVET NUT HEX M6    1
# 19                        RIVET NUT HEX M6    1
# 20      ASSEMBLY WATER CHANNEL TAILGA LEFT    1
# 21          JEP  ASM WATER CNL TAILGA LEFT    1
# 22                    WATER CHANNEL TAILGA    1
# 23                FN  WATER CHANNEL TAILGA    1
# 24                  NUT SQUARE WELD M6 STL    3
# 25                HOLDER BRACKET GAS STRUT    1
# 26              FNHOLDER BRACKET GAS STRUT    1
# 27                THREADED PLATE M10 STEEL    1
# 28         ASSEMBLY SIDE FRAME OUTER RIGHT    1
# 29                      BODY SIDE PANEL RH    1
# ..                                     ...  ...
# 170                 NUT SQUARE WELD M6 STL    4
# 171                   EXPANDABLE FOAM PART    1
# 172       ASSEMBLY SILL REINFORCEMENT LEFT    1
# 173  JEP  ASSEMBLY SILL REINFORCEMENT LEFT    1
# 174                   REINFORCE SILL TOP H    1
# 175         ASSEMBLY SILL REINF INNER LEFT    1
# 176    JEP  ASSEMBLY SILL REINF INNER LEFT    1
# 177                      SILL MIDDLE SHEET    1
# 178              SILL INNER REINF LOWER LH    1
# 179         ASSEMBLY WHEELHOUSE OUTER LEFT    1
# 180    JEP  ASSEMBLY WHEELHOUSE OUTER LEFT    1
# 181               EXTENSION WHELLHOU OUTER    1
# 182                       WHEELHOUSE OUTER    1
# 183                   FN  WHEELHOUSE OUTER    1
# 184                 NUT SQUARE WELD M6 STL    4
# 185      ASSEMBLY SIDE FRAME INNER 2 RIGHT    1
# 186      ASSEMBLY SIDE FRAME INNER 1 RIGHT    1
# 187                   EXPANDABLE FOAM PART    1
# 188                   EXPANDABLE FOAM PART    1
# 189                   EXPANDABLE FOAM PART    1
# 190                 SWIM NUT DOOR A PILLAR    1
# 191                   HINGE REINFOR A P UP    1
# 192                    SILL OUTER C PILLAR    1
# 193                             SILL OUTER    1
# 194                   C PILLAR LOWER FRONT    1
# 195     ASSEMBLY LONGITUDE FRONT UPR RIGHT    1
# 196                    LONGITUDE FR UP OUT    1
# 197                  FNLONGITUDE FR UP OUT    1
# 198                 NUT SQUARE WELD M6 STL    5
# 199                       REINF HOOD HINGE    1
#
#                                Description      UOM Purchased Part Type  \
# 0                            PHTM EC001 VP  EA EACH             Phantom
# 1                              PHTM BIW VP  EA EACH             Phantom
# 2           PHTM BIW BODY STRUCTURE ASM VP  EA EACH             Phantom
# 3                      COMPLETE WELDED BIW  EA EACH                Make
# 4               JOINING ELEMENTS UPPERBODY  EA EACH             Phantom
# 5                         STUDS UPPER BODY  EA EACH             Phantom
# 6                   ASSEMBLY OUTER FRAMING  EA EACH                Make
# 7              JEP  ASSEMBLY OUTER FRAMING  EA EACH             Phantom
# 8           ASSEMBLY SIDE FRAME OUTER LEFT  EA EACH                Make
# 9      JEP  ASSEMBLY SIDE FRAME OUTER LEFT  EA EACH             Phantom
# 10                      BODY SIDE PANEL LH  EA EACH                Make
# 11                         REARLIGHT SHEET  EA EACH                 Buy
# 12                           HOLDER FENDER  EA EACH                 Buy
# 13                         FNHOLDER FENDER  EA EACH             Phantom
# 14                        RIVET NUT HEX M6  EA EACH                 Buy
# 15                           HOLDER FENDER  EA EACH                 Buy
# 16                         FNHOLDER FENDER  EA EACH             Phantom
# 17                        RIVET NUT HEX M6  EA EACH                 Buy
# 18                        RIVET NUT HEX M6  EA EACH                 Buy
# 19                        RIVET NUT HEX M6  EA EACH                 Buy
# 20      ASSEMBLY WATER CHANNEL TAILGA LEFT  EA EACH                 Buy
# 21          JEP  ASM WATER CNL TAILGA LEFT  EA EACH             Phantom
# 22                    WATER CHANNEL TAILGA  EA EACH                 Buy
# 23                FN  WATER CHANNEL TAILGA  EA EACH             Phantom
# 24                  NUT SQUARE WELD M6 STL  EA EACH                 Buy
# 25                HOLDER BRACKET GAS STRUT  EA EACH                 Buy
# 26              FNHOLDER BRACKET GAS STRUT  EA EACH             Phantom
# 27                THREADED PLATE M10 STEEL  EA EACH                 Buy
# 28         ASSEMBLY SIDE FRAME OUTER RIGHT  EA EACH                Make
# 29                      BODY SIDE PANEL RH  EA EACH                Make
# ..                                     ...      ...                 ...
# 170                 NUT SQUARE WELD M6 STL  EA EACH                 Buy
# 171                   EXPANDABLE FOAM PART      NaN                 NaN
# 172       ASSEMBLY SILL REINFORCEMENT LEFT  EA EACH                 Buy
# 173  JEP  ASSEMBLY SILL REINFORCEMENT LEFT  EA EACH             Phantom
# 174                   REINFORCE SILL TOP H  EA EACH                 Buy
# 175         ASSEMBLY SILL REINF INNER LEFT  EA EACH                 Buy
# 176    JEP  ASSEMBLY SILL REINF INNER LEFT  EA EACH             Phantom
# 177                      SILL MIDDLE SHEET  EA EACH                 Buy
# 178                 SILL INNER REINF LOWER  EA EACH                 Buy
# 179         ASSEMBLY WHEELHOUSE OUTER LEFT  EA EACH                 Buy
# 180    JEP  ASSEMBLY WHEELHOUSE OUTER LEFT  EA EACH             Phantom
# 181               EXTENSION WHELLHOU OUTER  EA EACH                 Buy
# 182                       WHEELHOUSE OUTER  EA EACH                 Buy
# 183                   FN  WHEELHOUSE OUTER  EA EACH             Phantom
# 184                 NUT SQUARE WELD M6 STL  EA EACH                 Buy
# 185      ASSEMBLY SIDE FRAME INNER 2 RIGHT  EA EACH                 Buy
# 186      ASSEMBLY SIDE FRAME INNER 1 RIGHT  EA EACH                 Buy
# 187                   EXPANDABLE FOAM PART  EA EACH                 Buy
# 188                   EXPANDABLE FOAM PART      NaN                 Buy
# 189                   EXPANDABLE FOAM PART      NaN                 Buy
# 190                 SWIM NUT DOOR A PILLAR  EA EACH                 Buy
# 191                   HINGE REINFOR A P UP  EA EACH                 Buy
# 192                    SILL OUTER C PILLAR  EA EACH                 Buy
# 193                             SILL OUTER  EA EACH                 Buy
# 194                   C PILLAR LOWER FRONT  EA EACH                 Buy
# 195     ASSEMBLY LONGITUDE FRONT UPR RIGHT  EA EACH                 Buy
# 196                    LONGITUDE FR UP OUT  EA EACH                 Buy
# 197                  FNLONGITUDE FR UP OUT  EA EACH             Phantom
# 198                 NUT SQUARE WELD M6 STL  EA EACH                 Buy
# 199                       REINF HOOD HINGE  EA EACH                 Buy
#
#      Maturity Part Type                   System                    SubSystem  \
# 0     In Work   Phantom  Z Vehicle Top Level Cfg                       Z Z NA
# 1     In Work   Phantom                    A BIW                       A Z NA
# 2     In Work   Phantom                    A BIW  A G Body Structure Assembly
# 3     In Work  Assembly                    A BIW  A G Body Structure Assembly
# 4     In Work   Phantom                    A BIW  A G Body Structure Assembly
# 5     In Work   Phantom                    A BIW  A G Body Structure Assembly
# 6     In Work  Assembly                    A BIW           A E Side Structure
# 7     In Work   Phantom                    A BIW           A E Side Structure
# 8     In Work  Assembly                    A BIW           A E Side Structure
# 9     In Work   Phantom                    A BIW           A E Side Structure
# 10   Released      Part                      NaN                          NaN
# 11    In Work      Part                    A BIW           A E Side Structure
# 12    In Work      Part                    A BIW           A E Side Structure
# 13    In Work   Phantom                    A BIW           A E Side Structure
# 14   Released      Part              Y Fasteners                    Y F Rivet
# 15    In Work      Part                    A BIW           A E Side Structure
# 16    In Work   Phantom                    A BIW           A E Side Structure
# 17   Released      Part              Y Fasteners                    Y F Rivet
# 18   Released      Part              Y Fasteners                    Y F Rivet
# 19   Released      Part              Y Fasteners                    Y F Rivet
# 20    In Work  Assembly                    A BIW           A E Side Structure
# 21    In Work   Phantom                    A BIW           A E Side Structure
# 22    In Work      Part                    A BIW           A E Side Structure
# 23    In Work   Phantom                    A BIW           A E Side Structure
# 24   Released      Part              Y Fasteners                      Y D Nut
# 25    In Work      Part                    A BIW           A E Side Structure
# 26    In Work   Phantom                    A BIW           A E Side Structure
# 27   Released      Part                    A BIW           A C Rear Underbody
# 28    In Work  Assembly                    A BIW           A E Side Structure
# 29   Released      Part                      NaN                          NaN
# ..        ...       ...                      ...                          ...
# 170  Released      Part              Y Fasteners                      Y D Nut
# 171   In Work       NaN                    A BIW                      A J NVH
# 172   In Work  Assembly                    A BIW           A E Side Structure
# 173   In Work   Phantom                    A BIW           A E Side Structure
# 174   In Work      Part                    A BIW           A E Side Structure
# 175   In Work  Assembly                    A BIW           A E Side Structure
# 176   In Work   Phantom                    A BIW           A E Side Structure
# 177   In Work      Part                    A BIW           A E Side Structure
# 178   In Work      Part                    A BIW           A E Side Structure
# 179   In Work  Assembly                    A BIW           A E Side Structure
# 180   In Work   Phantom                    A BIW           A E Side Structure
# 181   In Work      Part                    A BIW           A E Side Structure
# 182   In Work      Part                    A BIW           A E Side Structure
# 183   In Work   Phantom                    A BIW           A E Side Structure
# 184  Released      Part              Y Fasteners                      Y D Nut
# 185   In Work  Assembly                    A BIW           A E Side Structure
# 186   In Work  Assembly                    A BIW           A E Side Structure
# 187   In Work       NaN                    A BIW                      A J NVH
# 188   In Work       NaN                    A BIW                      A J NVH
# 189   In Work       NaN                    A BIW                      A J NVH
# 190   In Work      Part                    A BIW           A E Side Structure
# 191   In Work      Part                    A BIW           A E Side Structure
# 192   In Work  Assembly                    A BIW           A E Side Structure
# 193   In Work      Part                    A BIW           A E Side Structure
# 194   In Work      Part                    A BIW           A E Side Structure
# 195   In Work  Assembly                    A BIW           A E Side Structure
# 196   In Work      Part                    A BIW           A E Side Structure
# 197   In Work   Phantom                    A BIW           A E Side Structure
# 198  Released      Part              Y Fasteners                      Y D Nut
# 199   In Work      Part                    A BIW           A E Side Structure
#
#     Legacy Part Number Legacy Part Revision Effectivity
# 0                  NaN                  NaN         NaN
# 1                  NaN                  NaN         NaN
# 2                  NaN                  NaN         NaN
# 3     EC001_02_130_000                  NaN         NaN
# 4                  NaN                  NaN         NaN
# 5                  NaN                  NaN         NaN
# 6     EC001_02_140_000                  NaN         NaN
# 7                  NaN                  NaN         NaN
# 8     EC001_02_423_000                  NaN         NaN
# 9                  NaN                  NaN         NaN
# 10    EC001_02_423_201                   26         NaN
# 11    EC001_02_423_203                   25         NaN
# 12    EC001_02_423_211                   12         NaN
# 13                 NaN                  NaN         NaN
# 14    EC001_02_999_020                    0         NaN
# 15    EC001_02_423_221                    9         NaN
# 16                 NaN                  NaN         NaN
# 17    EC001_02_999_020                    0         NaN
# 18    EC001_02_999_020                    0         NaN
# 19    EC001_02_999_020                    0         NaN
# 20    EC001_02_427_000                  NaN         NaN
# 21                 NaN                  NaN         NaN
# 22    EC001_02_423_205                   22         NaN
# 23                 NaN                  NaN         NaN
# 24    EC001_02_999_012                    0         NaN
# 25    EC001_02_423_217                   11         NaN
# 26                 NaN                  NaN         NaN
# 27    EC001_02_999_007                  NaN         NaN
# 28      EC001_02_424_0                  NaN         NaN
# 29    EC001_02_423_202                   21         NaN
# ..                 ...                  ...         ...
# 170   EC001_02_999_012                    0         NaN
# 171                NaN                  NaN         NaN
# 172   EC001_02_449_000                  NaN         NaN
# 173                NaN                  NaN         NaN
# 174   EC001_02_449_609                   13         NaN
# 175   EC001_02_463_000                  NaN         NaN
# 176                NaN                  NaN         NaN
# 177   EC001_02_449_603                   17         NaN
# 178   EC001_02_301_671                   16         NaN
# 179   EC001_02_341_000                  NaN         NaN
# 180                NaN                  NaN         NaN
# 181   EC001_02_341_123                   20         NaN
# 182   EC001_02_341_121                   23         NaN
# 183                NaN                  NaN         NaN
# 184   EC001_02_999_012                    0         NaN
# 185   EC001_02_320_000                  NaN         NaN
# 186   EC001_02_324_000                  NaN         NaN
# 187                NaN                  NaN         NaN
# 188                NaN                  NaN         NaN
# 189                NaN                  NaN         NaN
# 190   EC001_02_999_127                    4         NaN
# 191   EC001_02_445_404                   20         NaN
# 192       EC001_02_460                  NaN         NaN
# 193   EC001_02_449_602                   17         NaN
# 194   EC001_02_451_702                   15         NaN
# 195   EC001_02_454_000                  NaN         NaN
# 196   EC001_02_453_804                   22         NaN
# 197                NaN                  NaN         NaN
# 198   EC001_02_999_012                    0         NaN
# 199   EC001_02_453_808                    7         NaN
#
# [200 rows x 17 columns]

# %%
identifier_parent = CAD_BOM.loc[1].Identifier
PN_parent = CAD_BOM[CAD_BOM["Identifier"]==identifier_parent]["Byton PN"]
if PN_parent.empty == True:
    PN_parent = ""
else:
    PN_parent = PN_parent.values
CAD_BOM.loc[2, ["Parent"]] = PN_parent
CAD_BOM.loc[2]
# Out:
# Level                                                1
# Parent                                  AAAZ000002NN03
# Identifier                                         1|1
# Byton PN                                AAAG000002NN03
# Revision                                           A.1
# Title                   PHTM BIW BODY STRUCTURE ASM VP
# QTY                                                  1
# Description             PHTM BIW BODY STRUCTURE ASM VP
# UOM                                            EA EACH
# Purchased Part Type                            Phantom
# Maturity                                       In Work
# Part Type                                      Phantom
# System                                           A BIW
# SubSystem                  A G Body Structure Assembly
# Legacy Part Number                                 NaN
# Legacy Part Revision                               NaN
# Effectivity                                        NaN
# Name: 2, dtype: object

# %%
identifier = "2|2"
    
identifier_parent = identifier[0:-2]
if identifier_parent == '':
    identifier_parent = ''
elif identifier_parent[-1]=='|':
    identifier_parent = identifier_parent[0:-1]
else:
    identifier_parent = identifier_parent
print(identifier_parent)
# Out:
# 2
